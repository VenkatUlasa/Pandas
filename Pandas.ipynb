# %% [markdown]
# ##Pandas :
#
# We use Pandas in data science and data analysis because it provides powerful tools for working with structured data. It simplifies data manipulation, analysis, and cleaning tasks, making it easier to handle data from various sources (like Excel, CSV files, SQL databases, etc.). Here are the key reasons why Pandas is so widely used:
#
#
#
# *   Series:
#  A one-dimensional array-like structure, similar to a list, but with labeled indices.
# *   DataFrame:
# A two-dimensional, tabular data structure with labeled axes (rows and columns), similar to a table in a relational database or a spreadsheet. It’s the core data structure in Pandas for working with datasets.

# %% [markdown]
# ###in Pandas
#
#
# *   axis = 0   -> rows
# *   axis = 1   -> columns

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# Series;
arr = np.array([10,11,12,13,14,15])

d = pd.Series(arr)
d
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# dtype: int64

# %%
arr = np.array([10,11,12,13,14,15])

d = pd.Series(arr,index=['r1','r2','r3','r4','r5','r6'])  # updating row names using index;
d
# Out:
# r1    10
# r2    11
# r3    12
# r4    13
# r5    14
# r6    15
# dtype: int64

# %% [markdown]
# ## DataFrame

# %%
# DataFrame;
a = {'Employee_name' : ['varma','renu','ganesh','naveen','uday','pavan'],
     'Employee_age' : [24,25,23,26,22,28],
     "Location" : ['HYB',"BNGLR","VZA","KMM","BOM","DHL"],
     "Salary" : ['10L',"6L",'13L','8L',"5L",'15L'],
     "Company" : ['IBM','TCS',"Meta",'ACC',"Google","Amazon"],
     }

# %%
D = pd.DataFrame(a)
D
# Out:
#   Employee_name  Employee_age Location Salary Company
# 0         varma            24      HYB    10L     IBM
# 1          renu            25    BNGLR     6L     TCS
# 2        ganesh            23      VZA    13L    Meta
# 3        naveen            26      KMM     8L     ACC
# 4          uday            22      BOM     5L  Google
# 5         pavan            28      DHL    15L  Amazon

# %%
 # Updating row namres ;
 d = pd.DataFrame(a,index = ['r1','r2','r3','r4','r5','r6'])
 d
# Out:
#    Employee_name  Employee_age Location Salary Company
# r1         varma            24      HYB    10L     IBM
# r2          renu            25    BNGLR     6L     TCS
# r3        ganesh            23      VZA    13L    Meta
# r4        naveen            26      KMM     8L     ACC
# r5          uday            22      BOM     5L  Google
# r6         pavan            28      DHL    15L  Amazon

# %%
# getting all row names
d.index
# Out:
# Index(['r1', 'r2', 'r3', 'r4', 'r5', 'r6'], dtype='object')

# %%
# getting all column names;
d.columns
# Out:
# Index(['Employee_name', 'Employee_age', 'Location', 'Salary', 'Company'], dtype='object')

# %%
 d = pd.DataFrame(a)
 d
# Out:
#   Employee_name  Employee_age Location Salary Company
# 0         varma            24      HYB    10L     IBM
# 1          renu            25    BNGLR     6L     TCS
# 2        ganesh            23      VZA    13L    Meta
# 3        naveen            26      KMM     8L     ACC
# 4          uday            22      BOM     5L  Google
# 5         pavan            28      DHL    15L  Amazon

# %%
# Updating old value with new value;

d['Location'][2] = "Chennai"
d
# Out:
#   Employee_name  Employee_age Location Salary Company
# 0         varma            24      HYB    10L     IBM
# 1          renu            25    BNGLR     6L     TCS
# 2        ganesh            23  Chennai    13L    Meta
# 3        naveen            26      KMM     8L     ACC
# 4          uday            22      BOM     5L  Google
# 5         pavan            28      DHL    15L  Amazon

# %%
# acceessing multiple values from same column;

d['Location'][2:5]
# Out:
# 2    Chennai
# 3        KMM
# 4        BOM
# Name: Location, dtype: object

# %%
# accessing multiple values from multiple columns;
# using iloc[]

d.iloc[2:5,1:4]
# Out:
#    Employee_age Location Salary
# 2            23  Chennai    13L
# 3            26      KMM     8L
# 4            22      BOM     5L

# %%
# accessing multiple values from multiple columns;
# using loc[]

d.loc[1:4,"Employee_name":"Salary"]    # Here 1 and 4 are not index values these are row names.
# Out:
#   Employee_name  Employee_age Location Salary
# 1          renu            25    BNGLR     6L
# 2        ganesh            23  Chennai    13L
# 3        naveen            26      KMM     8L
# 4          uday            22      BOM     5L

# %%
d
# Out:
#   Employee_name  Employee_age Location Salary Company
# 0         varma            24      HYB    10L     IBM
# 1          renu            25    BNGLR     6L     TCS
# 2        ganesh            23  Chennai    13L    Meta
# 3        naveen            26      KMM     8L     ACC
# 4          uday            22      BOM     5L  Google
# 5         pavan            28      DHL    15L  Amazon

# %%
# accessing perticular row with all the values accoring to columns;
d.loc[2,:]
# Out:
# Employee_name     ganesh
# Employee_age          23
# Location         Chennai
# Salary               13L
# Company             Meta
# Name: 2, dtype: object

# %%
d.iloc[4,:]
# Out:
# Employee_name      uday
# Employee_age         22
# Location            BOM
# Salary               5L
# Company          Google
# Name: 4, dtype: object

# %%
d
# Out:
#   Employee_name  Employee_age Location Salary Company
# 0         varma            24      HYB    10L     IBM
# 1          renu            25    BNGLR     6L     TCS
# 2        ganesh            23  Chennai    13L    Meta
# 3        naveen            26      KMM     8L     ACC
# 4          uday            22      BOM     5L  Google
# 5         pavan            28      DHL    15L  Amazon

# %%
# rename() -> it is used to rename column name or row name;

d = d.rename(columns={"Salary":"Income"})

# %%
d
# Out:
#   Employee_name  Employee_age Location Income Company
# 0         varma            24      HYB    10L     IBM
# 1          renu            25    BNGLR     6L     TCS
# 2        ganesh            23  Chennai    13L    Meta
# 3        naveen            26      KMM     8L     ACC
# 4          uday            22      BOM     5L  Google
# 5         pavan            28      DHL    15L  Amazon

# %%
# removing one column using drop() and axis = 1 ;

d = d.drop(['Employee_age'],axis = 1)  # it removes the specified column
d
# Out:
#    Employee_name Location Salary Company
# r1         varma      HYB    10L     IBM
# r2          renu    BNGLR     6L     TCS
# r3        ganesh      VZA    13L    Meta
# r4        naveen      KMM     8L     ACC
# r5          uday      BOM     5L  Google
# r6         pavan      DHL    15L  Amazon

# %%
# adding new column .
d["Experience"] = [2,4,3,5,1,2]

# %%
d
# Out:
#   Employee_name Location Income Company  Experience
# 0         varma      HYB    10L     IBM           2
# 1          renu    BNGLR     6L     TCS           4
# 2        ganesh  Chennai    13L    Meta           3
# 3        naveen      KMM     8L     ACC           5
# 4          uday      BOM     5L  Google           1
# 5         pavan      DHL    15L  Amazon           2

# %%
# Saving the data into a excel sheet with some name ;

d.to_csv("Employee_Details.csv",index=False)

# %%
# Reading CSV file using URL : we can use file path if the file is downloaded ;
# Load Titanic dataset
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# head() => returns specified no of rows from the top of the data set;

df.head() # by default it returns 5 rows and we can specify no of rows we want to print ;
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# tail() => returns specified no of rows from the bottom of the data set;

df.tail(10) # by default it returns 5 rows and we can specify no of rows we want to print ;
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# sample() => this is same like head() but it returns the rows randomly from given dataset;
df.sample(10) # By default it returns 1 row but we can specify ;
# Out:
#      PassengerId  Survived  Pclass  \
# 377          378         0       1
# 774          775         1       2
# 385          386         0       2
# 663          664         0       3
# 665          666         0       2
# 487          488         0       1
# 560          561         0       3
# 314          315         0       2
# 850          851         0       3
# 230          231         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 377                     Widener, Mr. Harry Elkins    male  27.0      0      2
# 774         Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.0      1      3
# 385                     Davies, Mr. Charles Henry    male  18.0      0      0
# 663                              Coleff, Mr. Peju    male  36.0      0      0
# 665                            Hickman, Mr. Lewis    male  32.0      2      0
# 487                       Kent, Mr. Edward Austin    male  58.0      0      0
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
# info() => it returns complete information about the given dataset;
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# removing some unwanted columns from dataset;
df = df.drop(['PassengerId','Name','Ticket'],axis = 1)  # it removes the column is existed otherwise it returns an error.

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
# unique()
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# value_counts() => it returns the total count of each unique value from specified column.

df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# filling null values with a value.
# fillna()
df["Age"] = df["Age"].fillna(10)

# %%
df["Age"].isnull().sum()  # returns 0 because all null values filled with 10;
# Out:
# 0

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 9)

# %%
# removing rows having null values;
# dropna()
df = df.dropna()

# %%
df.shape # we removed all the rows having null values;
# Out:
# (202, 9)

# %%
df.head()
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 1          1       1  female  38.0      1      0  71.2833   C85        C
# 3          1       1  female  35.0      1      0  53.1000  C123        S
# 6          0       1    male  54.0      0      0  51.8625   E46        S
# 10         1       3  female   4.0      1      1  16.7000    G6        S
# 11         1       1  female  58.0      0      0  26.5500  C103        S

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
# all the columns with only numerical values;

num_cols = df.select_dtypes(exclude='object')  # exclude='object' means i don't need columns with object(text) data type;

# %%
num_cols # it returns only columns with numerical values;
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare
# 1           1       1  38.0      1      0  71.2833
# 3           1       1  35.0      1      0  53.1000
# 6           0       1  54.0      0      0  51.8625
# 10          1       3   4.0      1      1  16.7000
# 11          1       1  58.0      0      0  26.5500
# ..        ...     ...   ...    ...    ...      ...
# 871         1       1  47.0      1      1  52.5542
# 872         0       1  33.0      0      0   5.0000
# 879         1       1  56.0      0      1  83.1583
# 887         1       1  19.0      0      0  30.0000
# 889         1       1  26.0      0      0  30.0000
#
# [202 rows x 6 columns]

# %%
# now columns with text values;

txt_cols = df.select_dtypes(include = "object")

# %%
txt_cols
# Out:
#         Sex        Cabin Embarked
# 1    female          C85        C
# 3    female         C123        S
# 6      male          E46        S
# 10   female           G6        S
# 11   female         C103        S
# ..      ...          ...      ...
# 871  female          D35        S
# 872    male  B51 B53 B55        S
# 879  female          C50        C
# 887  female          B42        S
# 889    male         C148        C
#
# [202 rows x 3 columns]

# %%
# we need to add two data sets side by side ;
# concat() it is the function used to add multiple data sets with having equal number of rows side by side;
n_ds = pd.concat([num_cols,txt_cols],axis = 1)
n_ds
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare     Sex        Cabin  \
# 1           1       1  38.0      1      0  71.2833  female          C85
# 3           1       1  35.0      1      0  53.1000  female         C123
# 6           0       1  54.0      0      0  51.8625    male          E46
# 10          1       3   4.0      1      1  16.7000  female           G6
# 11          1       1  58.0      0      0  26.5500  female         C103
# ..        ...     ...   ...    ...    ...      ...     ...          ...
# 871         1       1  47.0      1      1  52.5542  female          D35
# 872         0       1  33.0      0      0   5.0000    male  B51 B53 B55
# 879         1       1  56.0      0      1  83.1583  female          C50
# 887         1       1  19.0      0      0  30.0000  female          B42
# 889         1       1  26.0      0      0  30.0000    male         C148
#
#     Embarked
# 1          C
# 3          S
# 6          S
# 10         S
# 11         S
# ..       ...
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# map()

df["Sex"] = df["Sex"].map({'male':1,'female':2}).astype(int)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    2  38.0      1      0
# 2                             Heikkinen, Miss. Laina    2  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    2  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df = df.drop(["PassengerId","Name","Ticket"],axis = 1)

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    1  22.0      1      0   7.2500   NaN        S
# 1         1       1    2  38.0      1      0  71.2833   C85        C
# 2         1       3    2  26.0      0      0   7.9250   NaN        S
# 3         1       1    2  35.0      1      0  53.1000  C123        S
# 4         0       3    1  35.0      0      0   8.0500   NaN        S

# %%
# We can find the mean() , median() and mode() for the columns having only numerical values.
# in this i am taking the column "Fare"

print(df["Fare"].mean()) # prints mean value.
print(df["Fare"].median())  # prints median value.
print(df["Fare"].mode()) # prints mode value.
# Out:
# 32.204207968574636
# 14.4542
# 0    8.05
# Name: Fare, dtype: float64

# %%
# groupby()

a = {
    "Animal" : ["Lion","Deer","Lion","Deer"],
    "Speed"  : [60,40,70,55]
}

# %%
b = pd.DataFrame(a)
b
# Out:
#   Animal  Speed
# 0   Lion     60
# 1   Deer     40
# 2   Lion     70
# 3   Deer     55

# %%
b.groupby(["Animal"]).median()
# Out:
#         Speed
# Animal
# Deer     47.5
# Lion     65.0
